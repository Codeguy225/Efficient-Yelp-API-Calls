# %% [markdown]
# # **Efficient Yelp API Calls**

# %% [markdown]
# **Name:** **Derek Overton**
#
# **Date:** **2/28/2023**
#
# **Assignment:** **Efficient Yelp API Calls**

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# # **Load Credentials and Create Yelp API Object**

# %%
# Load API Credentials:
with open('/Users/talen/.secret/yelp_api.json','r') as f:
    login = json.load(f)

# %%
# Show Login Keys:
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'],timeout_s=5.0)

# %% [markdown]
# # **Defining Search Terms**

# %%
# set our API call parameters and filename before the first call
location = 'New Orleans, LA 70118'
term = 'Gumbo'

# %%
location.split(',')[0]
# Out:
# 'New Orleans'

# %%
## Specify fodler for saving data


FOLDER ='Data/'

os.makedirs(FOLDER,exist_ok=True)

# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/New Orleans-Gumbo.json'

# %% [markdown]
# ## **Check if Json File exists and Create it if it doesn't**

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)

## If it does not exist: 
if file_exists ==False:
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder,exist_ok=True)
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE,'w')as f:
        json.dump([],f)
        
## If it exists, inform user
else:
       print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/New Orleans-Gumbo.json already exists.

# %% [markdown]
# ## **Make the first API call to get the first page of data**

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term=term,location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 437

# %%
results['region']
# Out:
# {'center': {'longitude': -90.12393951416016, 'latitude': 29.948082696672913}}

# %%
results['businesses']
# Out:
# [{'id': 'qb28j-FNX1_6xm7u372TZA',
#   'alias': 'gumbo-shop-new-orleans-2',
#   'name': 'Gumbo Shop',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Nhkz7Zbo3F5aQ0hcx_R-Ig/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gumbo-shop-new-orleans-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 4300,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.957692211278957,
#    'longitude': -90.06452299790816},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '630 Saint Peter St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70116',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['630 Saint Peter St', 'New Orleans, LA 70116']},
#   'phone': '+15045251486',
#   'display_phone': '(504) 525-1486',
#   'distance': 5823.251010795227},
#  {'id': 'mhrW9O0O5hXGXGnEYBVoag',
#   'alias': 'jacques-imos-cafe-new-orleans',
#   'name': "Jacques-Imo's Cafe",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LLFEQtqHuJ2YOLLstWwBRg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jacques-imos-cafe-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2572,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.94902, 'longitude': -90.13224},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '8324 Oak St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70118',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['8324 Oak St', 'New Orleans, LA 70118']},
#   'phone': '+15048610886',
#   'display_phone': '(504) 861-0886',
#   'distance': 807.133049043754},
#  {'id': 'bp5Mk2d0qofUeF5uLauIbg',
#   'alias': 'chef-rons-gumbo-stop-metairie',
#   'name': "Chef Ron's Gumbo Stop",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HjPkhoaaR4PmWgKANWlMyA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chef-rons-gumbo-stop-metairie?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1495,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9942752940439,
#    'longitude': -90.1550585031509},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '2309 N Causeway Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Metairie',
#    'zip_code': '70001',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['2309 N Causeway Blvd', 'Metairie, LA 70001']},
#   'phone': '+15048352022',
#   'display_phone': '(504) 835-2022',
#   'distance': 5947.073271811802},
#  {'id': 'SJIQFKTW6uUsOo29w9IHxw',
#   'alias': 'mambos-new-orleans',
#   'name': "Mambo's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tarz6Y_fjU42sDk_SwBUPA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mambos-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1807,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.95668, 'longitude': -90.06772},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '411 Bourbon St',
#    'address2': '',
#    'address3': None,
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['411 Bourbon St', 'New Orleans, LA 70130']},
#   'phone': '+15044073717',
#   'display_phone': '(504) 407-3717',
#   'distance': 5506.406813933842},
#  {'id': '7CRox7xpb3vNCEe7FZ6zgA',
#   'alias': 'high-hat-cafe-new-orleans',
#   'name': 'High Hat Cafe',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/693NJuINMNlpXrtqTvdXaA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/high-hat-cafe-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 602,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'soulfood', 'title': 'Soul Food'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.935093648757825,
#    'longitude': -90.10434171534023},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '4500 Freret St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70115',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['4500 Freret St', 'New Orleans, LA 70115']},
#   'phone': '+15047541336',
#   'display_phone': '(504) 754-1336',
#   'distance': 2377.35828261402},
#  {'id': 'rsMbMeW7IbXxPFh4WwbddQ',
#   'alias': 'boucherie-new-orleans',
#   'name': 'Boucherie',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Li4x5QCdQ6tRRiK0nF4Gxw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/boucherie-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 598,
#   'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.949828919319, 'longitude': -90.1278002441803},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8115 Jeannette St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70118',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['8115 Jeannette St', 'New Orleans, LA 70118']},
#   'phone': '+15048625514',
#   'display_phone': '(504) 862-5514',
#   'distance': 419.5996671578709},
#  {'id': 'X1aAjsufci2ibaxSbhFl4Q',
#   'alias': 'ajun-cajun-new-orleans',
#   'name': 'Ajun Cajun',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6S-0s6yygHQdOmojVqFDRQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ajun-cajun-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 67,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.950121, 'longitude': -90.132809},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '8433 Oak St',
#    'address2': '',
#    'address3': None,
#    'city': 'New Orleans',
#    'zip_code': '70118',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['8433 Oak St', 'New Orleans, LA 70118']},
#   'phone': '+15048667077',
#   'display_phone': '(504) 866-7077',
#   'distance': 883.5746326704924},
#  {'id': '75FY8ZQx5nOWP0VFmNvWfw',
#   'alias': 'atchafalaya-restaurant-new-orleans',
#   'name': 'Atchafalaya Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/79CksDOOLNCwzgF74n-rFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/atchafalaya-restaurant-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2190,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9212715, 'longitude': -90.0878562},
#   'transactions': ['delivery'],
#   'price': '$$$',
#   'location': {'address1': '901 Louisiana Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70115',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['901 Louisiana Ave', 'New Orleans, LA 70115']},
#   'phone': '+15048919626',
#   'display_phone': '(504) 891-9626',
#   'distance': 4580.131480631949},
#  {'id': 'iYUwyARgC_RNPA1rTlL3-Q',
#   'alias': 'crabby-jacks-new-orleans',
#   'name': "Crabby Jack's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/R-uTGsAEcISnvLAlawpMIw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crabby-jacks-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 410,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9648, 'longitude': -90.13547},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '428 Jefferson Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70121',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['428 Jefferson Hwy', 'New Orleans, LA 70121']},
#   'phone': '+15048332722',
#   'display_phone': '(504) 833-2722',
#   'distance': 2158.681068104382},
#  {'id': 'iJiNZw2TEwB579dr6LyVZQ',
#   'alias': 'cooter-browns-new-orleans',
#   'name': "Cooter Brown's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C05Q6DSrvpiYXRnIDiPnYA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cooter-browns-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 539,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.94244, 'longitude': -90.13425},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '509 S Carrollton Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70118',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['509 S Carrollton Ave', 'New Orleans, LA 70118']},
#   'phone': '+15048669104',
#   'display_phone': '(504) 866-9104',
#   'distance': 1182.3586441128991},
#  {'id': '-VlBFlHwX-Pt6Xyzs9roGw',
#   'alias': 'superior-seafood-and-oyster-bar-new-orleans',
#   'name': 'Superior Seafood & Oyster Bar',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zKEO5hjYr-T7fy3gfwSFfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/superior-seafood-and-oyster-bar-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1806,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'brasseries', 'title': 'Brasseries'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.92623550149, 'longitude': -90.1016806155892},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4338 St Charles Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70115',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['4338 St Charles Ave', 'New Orleans, LA 70115']},
#   'phone': '+15042933474',
#   'display_phone': '(504) 293-3474',
#   'distance': 3240.644986319893},
#  {'id': '8UPv1p9GW-BiZtQqUt8nOA',
#   'alias': 'neyows-creole-cafe-new-orleans-3',
#   'name': "Neyow's Creole Cafe",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0qc-jcInmeINypAQGu3X3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/neyows-creole-cafe-new-orleans-3?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1930,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.9712, 'longitude': -90.09207},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3332 Bienville',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70119',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['3332 Bienville', 'New Orleans, LA 70119']},
#   'phone': '+15048275474',
#   'display_phone': '(504) 827-5474',
#   'distance': 4004.0443755030888},
#  {'id': 'A0DYN5wxygYnX_sL3HygvA',
#   'alias': 'gris-gris-new-orleans',
#   'name': 'Gris-Gris',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nC7HpoGt3_VOOOc3rzjFBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gris-gris-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 702,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'southern', 'title': 'Southern'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.93179, 'longitude': -90.07339},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1800 Magazine St',
#    'address2': '',
#    'address3': None,
#    'city': 'New Orleans',
#    'zip_code': '70130',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['1800 Magazine St', 'New Orleans, LA 70130']},
#   'phone': '+15042720241',
#   'display_phone': '(504) 272-0241',
#   'distance': 5198.22503832532},
#  {'id': 'pym7c6ZFEtmoH16xN2ApBg',
#   'alias': 'katies-restaurant-and-bar-new-orleans',
#   'name': "Katie's Restaurant & Bar",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/et28nBBFyVdqZh-OhtLk6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/katies-restaurant-and-bar-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 1484,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9730854034424,
#    'longitude': -90.0959091186523},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3701 Iberville St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70119',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['3701 Iberville St', 'New Orleans, LA 70119']},
#   'phone': '+15044886582',
#   'display_phone': '(504) 488-6582',
#   'distance': 3876.0652462757557},
#  {'id': 'WO-ofNAvSuJpdRt9Auon6w',
#   'alias': 'heard-dat-kitchen-new-orleans',
#   'name': 'Heard Dat Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/38ABHtRVXb6oKcRM9AvqAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/heard-dat-kitchen-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 617,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'soulfood', 'title': 'Soul Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9437066, 'longitude': -90.0861294},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2520 Felicity St',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70113',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['2520 Felicity St', 'New Orleans, LA 70113']},
#   'phone': '+15045104248',
#   'display_phone': '(504) 510-4248',
#   'distance': 3654.4355467667947},
#  {'id': 'ww3YJXu5c18aGZXWmm00qg',
#   'alias': 'café-amelie-new-orleans-2',
#   'name': 'Café Amelie',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/93q9x7v19HAAGczJ5TqiwQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/caf%C3%A9-amelie-new-orleans-2?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 2890,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.959713072343092,
#    'longitude': -90.06309559075224},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '900 Royal St',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70116',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['900 Royal St', 'New Orleans, LA 70116']},
#   'phone': '+15044128065',
#   'display_phone': '(504) 412-8065',
#   'distance': 6002.801051186518},
#  {'id': 'VVH6k9-ycttH3TV_lk5WfQ',
#   'alias': 'willie-maes-scotch-house-new-orleans',
#   'name': "Willie Mae's Scotch House",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-5ponMifvXGD3SXPITWcfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/willie-maes-scotch-house-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 3959,
#   'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.96916, 'longitude': -90.07893},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '2401 St Ann Sreet',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70119',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['2401 St Ann Sreet', 'New Orleans, LA 70119']},
#   'phone': '+15048229503',
#   'display_phone': '(504) 822-9503',
#   'distance': 4928.26481374652},
#  {'id': 'OSi2ColCxhS9oCoAUNbPig',
#   'alias': 'mandinas-restaurant-new-orleans',
#   'name': "Mandina's Restaurant",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YR-B0fiOGGyl-qMQmPDcng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mandinas-restaurant-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 762,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.97218, 'longitude': -90.09811},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3800 Canal St',
#    'address2': '',
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70119',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['3800 Canal St', 'New Orleans, LA 70119']},
#   'phone': '+15044829179',
#   'display_phone': '(504) 482-9179',
#   'distance': 3676.362638481573},
#  {'id': 'bWiOMj0g9ub53j1l8TJqSg',
#   'alias': 'hieux-boil-seafood-house-new-orleans',
#   'name': 'Hieux Boil Seafood House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/J-LtlhXB7clu1b-TS4RxtA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hieux-boil-seafood-house-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 129,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.969155501335425,
#    'longitude': -90.10574118031953},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '4077 Tulane Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70119',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['4077 Tulane Ave', 'New Orleans, LA 70119']},
#   'phone': '+15047660478',
#   'display_phone': '(504) 766-0478',
#   'distance': 2926.4618853839215},
#  {'id': 'SdU54YlTaCCFvtcfouoBpQ',
#   'alias': 'guys-po-boys-new-orleans',
#   'name': "Guy's Po Boys",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lGG73aUR_yIc01LMVuE_ag/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/guys-po-boys-new-orleans?adjust_creative=yju6_nc3KU6Is_FIzjjOVQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=yju6_nc3KU6Is_FIzjjOVQ',
#   'review_count': 369,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.9204354502892, 'longitude': -90.112764489333},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5259 Magazine St',
#    'address2': None,
#    'address3': '',
#    'city': 'New Orleans',
#    'zip_code': '70115',
#    'country': 'US',
#    'state': 'LA',
#    'display_address': ['5259 Magazine St', 'New Orleans, LA 70115']},
#   'phone': '+15048915025',
#   'display_phone': '(504) 891-5025',
#   'distance': 3257.3722380276854}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                        alias  \
# 0   qb28j-FNX1_6xm7u372TZA                     gumbo-shop-new-orleans-2
# 1   mhrW9O0O5hXGXGnEYBVoag                jacques-imos-cafe-new-orleans
# 2   bp5Mk2d0qofUeF5uLauIbg                chef-rons-gumbo-stop-metairie
# 3   SJIQFKTW6uUsOo29w9IHxw                           mambos-new-orleans
# 4   7CRox7xpb3vNCEe7FZ6zgA                    high-hat-cafe-new-orleans
# 5   rsMbMeW7IbXxPFh4WwbddQ                        boucherie-new-orleans
# 6   X1aAjsufci2ibaxSbhFl4Q                       ajun-cajun-new-orleans
# 7   75FY8ZQx5nOWP0VFmNvWfw           atchafalaya-restaurant-new-orleans
# 8   iYUwyARgC_RNPA1rTlL3-Q                     crabby-jacks-new-orleans
# 9   iJiNZw2TEwB579dr6LyVZQ                    cooter-browns-new-orleans
# 10  -VlBFlHwX-Pt6Xyzs9roGw  superior-seafood-and-oyster-bar-new-orleans
# 11  8UPv1p9GW-BiZtQqUt8nOA             neyows-creole-cafe-new-orleans-3
# 12  A0DYN5wxygYnX_sL3HygvA                        gris-gris-new-orleans
# 13  pym7c6ZFEtmoH16xN2ApBg        katies-restaurant-and-bar-new-orleans
# 14  WO-ofNAvSuJpdRt9Auon6w                heard-dat-kitchen-new-orleans
# 15  ww3YJXu5c18aGZXWmm00qg                    café-amelie-new-orleans-2
# 16  VVH6k9-ycttH3TV_lk5WfQ         willie-maes-scotch-house-new-orleans
# 17  OSi2ColCxhS9oCoAUNbPig              mandinas-restaurant-new-orleans
# 18  bWiOMj0g9ub53j1l8TJqSg         hieux-boil-seafood-house-new-orleans
# 19  SdU54YlTaCCFvtcfouoBpQ                     guys-po-boys-new-orleans
#
#                              name  \
# 0                      Gumbo Shop
# 1              Jacques-Imo's Cafe
# 2           Chef Ron's Gumbo Stop
# 3                         Mambo's
# 4                   High Hat Cafe
# 5                       Boucherie
# 6                      Ajun Cajun
# 7          Atchafalaya Restaurant
# 8                   Crabby Jack's
# 9                  Cooter Brown's
# 10  Superior Seafood & Oyster Bar
# 11            Neyow's Creole Cafe
# 12                      Gris-Gris
# 13       Katie's Restaurant & Bar
# 14              Heard Dat Kitchen
# 15                    Café Amelie
# 16      Willie Mae's Scotch House
# 17           Mandina's Restaurant
# 18       Hieux Boil Seafood House
# 19                  Guy's Po Boys
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/Nhkz7Z...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/LLFEQt...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/HjPkho...      False
# 3   https://s3-media4.fl.yelpcdn.com/bphoto/tarz6Y...      False
# 4   https://s3-media4.fl.yelpcdn.com/bphoto/693NJu...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/Li4x5Q...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/6S-0s6...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/79CksD...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/R-uTGs...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/C05Q6D...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/zKEO5h...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/0qc-jc...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/nC7Hpo...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/et28nB...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/38ABHt...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/93q9x7...      False
# 16  https://s3-media4.fl.yelpcdn.com/bphoto/-5ponM...      False
# 17  https://s3-media3.fl.yelpcdn.com/bphoto/YR-B0f...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/J-Ltlh...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/lGG73a...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/gumbo-shop-new-orlean...          4300
# 1   https://www.yelp.com/biz/jacques-imos-cafe-new...          2572
# 2   https://www.yelp.com/biz/chef-rons-gumbo-stop-...          1495
# 3   https://www.yelp.com/biz/mambos-new-orleans?ad...          1807
# 4   https://www.yelp.com/biz/high-hat-cafe-new-orl...           602
# 5   https://www.yelp.com/biz/boucherie-new-orleans...           598
# 6   https://www.yelp.com/biz/ajun-cajun-new-orlean...            67
# 7   https://www.yelp.com/biz/atchafalaya-restauran...          2190
# 8   https://www.yelp.com/biz/crabby-jacks-new-orle...           410
# 9   https://www.yelp.com/biz/cooter-browns-new-orl...           539
# 10  https://www.yelp.com/biz/superior-seafood-and-...          1806
# 11  https://www.yelp.com/biz/neyows-creole-cafe-ne...          1930
# 12  https://www.yelp.com/biz/gris-gris-new-orleans...           702
# 13  https://www.yelp.com/biz/katies-restaurant-and...          1484
# 14  https://www.yelp.com/biz/heard-dat-kitchen-new...           617
# 15  https://www.yelp.com/biz/caf%C3%A9-amelie-new-...          2890
# 16  https://www.yelp.com/biz/willie-maes-scotch-ho...          3959
# 17  https://www.yelp.com/biz/mandinas-restaurant-n...           762
# 18  https://www.yelp.com/biz/hieux-boil-seafood-ho...           129
# 19  https://www.yelp.com/biz/guys-po-boys-new-orle...           369
#
#                                            categories  rating  \
# 0       [{'alias': 'cajun', 'title': 'Cajun/Creole'}]     4.0
# 1       [{'alias': 'cajun', 'title': 'Cajun/Creole'}]     4.5
# 2   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 3   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 4   [{'alias': 'southern', 'title': 'Southern'}, {...     4.0
# 5   [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
# 6   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 7   [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 8   [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 9   [{'alias': 'sportsbars', 'title': 'Sports Bars...     4.0
# 10  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 11      [{'alias': 'cajun', 'title': 'Cajun/Creole'}]     4.0
# 12  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 13  [{'alias': 'tradamerican', 'title': 'American ...     4.5
# 14  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 15  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 16  [{'alias': 'southern', 'title': 'Southern'}, {...     4.5
# 17      [{'alias': 'cajun', 'title': 'Cajun/Creole'}]     4.0
# 18  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.0
# 19  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     4.5
#
#                                           coordinates  \
# 0   {'latitude': 29.957692211278957, 'longitude': ...
# 1      {'latitude': 29.94902, 'longitude': -90.13224}
# 2   {'latitude': 29.9942752940439, 'longitude': -9...
# 3      {'latitude': 29.95668, 'longitude': -90.06772}
# 4   {'latitude': 29.935093648757825, 'longitude': ...
# 5   {'latitude': 29.949828919319, 'longitude': -90...
# 6    {'latitude': 29.950121, 'longitude': -90.132809}
# 7   {'latitude': 29.9212715, 'longitude': -90.0878...
# 8       {'latitude': 29.9648, 'longitude': -90.13547}
# 9      {'latitude': 29.94244, 'longitude': -90.13425}
# 10  {'latitude': 29.92623550149, 'longitude': -90....
# 11      {'latitude': 29.9712, 'longitude': -90.09207}
# 12     {'latitude': 29.93179, 'longitude': -90.07339}
# 13  {'latitude': 29.9730854034424, 'longitude': -9...
# 14  {'latitude': 29.9437066, 'longitude': -90.0861...
# 15  {'latitude': 29.959713072343092, 'longitude': ...
# 16     {'latitude': 29.96916, 'longitude': -90.07893}
# 17     {'latitude': 29.97218, 'longitude': -90.09811}
# 18  {'latitude': 29.969155501335425, 'longitude': ...
# 19  {'latitude': 29.9204354502892, 'longitude': -9...
#
#                                   transactions price  \
# 0                                   [delivery]    $$
# 1                                   [delivery]   $$$
# 2                                     [pickup]    $$
# 3                           [delivery, pickup]    $$
# 4                                   [delivery]    $$
# 5                           [delivery, pickup]    $$
# 6                           [delivery, pickup]    $$
# 7                                   [delivery]   $$$
# 8                                   [delivery]    $$
# 9                                   [delivery]    $$
# 10                          [delivery, pickup]    $$
# 11                                          []    $$
# 12                                  [delivery]    $$
# 13                                  [delivery]    $$
# 14                          [delivery, pickup]    $$
# 15                                  [delivery]    $$
# 16                          [delivery, pickup]    $$
# 17                          [delivery, pickup]    $$
# 18  [restaurant_reservation, delivery, pickup]    $$
# 19                                  [delivery]    $$
#
#                                              location         phone  \
# 0   {'address1': '630 Saint Peter St', 'address2':...  +15045251486
# 1   {'address1': '8324 Oak St', 'address2': '', 'a...  +15048610886
# 2   {'address1': '2309 N Causeway Blvd', 'address2...  +15048352022
# 3   {'address1': '411 Bourbon St', 'address2': '',...  +15044073717
# 4   {'address1': '4500 Freret St', 'address2': '',...  +15047541336
# 5   {'address1': '8115 Jeannette St', 'address2': ...  +15048625514
# 6   {'address1': '8433 Oak St', 'address2': '', 'a...  +15048667077
# 7   {'address1': '901 Louisiana Ave', 'address2': ...  +15048919626
# 8   {'address1': '428 Jefferson Hwy', 'address2': ...  +15048332722
# 9   {'address1': '509 S Carrollton Ave', 'address2...  +15048669104
# 10  {'address1': '4338 St Charles Ave', 'address2'...  +15042933474
# 11  {'address1': '3332 Bienville', 'address2': '',...  +15048275474
# 12  {'address1': '1800 Magazine St', 'address2': '...  +15042720241
# 13  {'address1': '3701 Iberville St', 'address2': ...  +15044886582
# 14  {'address1': '2520 Felicity St', 'address2': N...  +15045104248
# 15  {'address1': '900 Royal St', 'address2': None,...  +15044128065
# 16  {'address1': '2401 St Ann Sreet', 'address2': ...  +15048229503
# 17  {'address1': '3800 Canal St', 'address2': '', ...  +15044829179
# 18  {'address1': '4077 Tulane Ave', 'address2': No...  +15047660478
# 19  {'address1': '5259 Magazine St', 'address2': N...  +15048915025
#
#      display_phone     distance
# 0   (504) 525-1486  5823.251011
# 1   (504) 861-0886   807.133049
# 2   (504) 835-2022  5947.073272
# 3   (504) 407-3717  5506.406814
# 4   (504) 754-1336  2377.358283
# 5   (504) 862-5514   419.599667
# 6   (504) 866-7077   883.574633
# 7   (504) 891-9626  4580.131481
# 8   (504) 833-2722  2158.681068
# 9   (504) 866-9104  1182.358644
# 10  (504) 293-3474  3240.644986
# 11  (504) 827-5474  4004.044376
# 12  (504) 272-0241  5198.225038
# 13  (504) 488-6582  3876.065246
# 14  (504) 510-4248  3654.435547
# 15  (504) 412-8065  6002.801051
# 16  (504) 822-9503  4928.264814
# 17  (504) 482-9179  3676.362638
# 18  (504) 766-0478  2926.461885
# 19  (504) 891-5025  3257.372238

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 22

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
   # The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
            
        ## save number of results for to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location=location,
                                        term=term, 
                                        offset=n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])

        with open(JSON_FILE,'w') as f:
            json.dump(previous_results,f)
            
    #What to do if we get an error/exception.
    except Exception as e: # saving the error message so we can print it.
        print('[!] ERROR: ',e)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                          alias  \
# 0  mhrW9O0O5hXGXGnEYBVoag  jacques-imos-cafe-new-orleans
# 1  bp5Mk2d0qofUeF5uLauIbg  chef-rons-gumbo-stop-metairie
# 2  SJIQFKTW6uUsOo29w9IHxw             mambos-new-orleans
# 3  7CRox7xpb3vNCEe7FZ6zgA      high-hat-cafe-new-orleans
# 4  rsMbMeW7IbXxPFh4WwbddQ          boucherie-new-orleans
#
#                     name                                          image_url  \
# 0     Jacques-Imo's Cafe  https://s3-media1.fl.yelpcdn.com/bphoto/LLFEQt...
# 1  Chef Ron's Gumbo Stop  https://s3-media1.fl.yelpcdn.com/bphoto/HjPkho...
# 2                Mambo's  https://s3-media4.fl.yelpcdn.com/bphoto/tarz6Y...
# 3          High Hat Cafe  https://s3-media4.fl.yelpcdn.com/bphoto/693NJu...
# 4              Boucherie  https://s3-media2.fl.yelpcdn.com/bphoto/Li4x5Q...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/jacques-imos-cafe-new...          2572
# 1      False  https://www.yelp.com/biz/chef-rons-gumbo-stop-...          1495
# 2      False  https://www.yelp.com/biz/mambos-new-orleans?ad...          1807
# 3      False  https://www.yelp.com/biz/high-hat-cafe-new-orl...           602
# 4      False  https://www.yelp.com/biz/boucherie-new-orleans...           598
#
#                                           categories  rating  \
# 0      [{'alias': 'cajun', 'title': 'Cajun/Creole'}]     4.5
# 1  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.5
# 2  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     4.0
# 3  [{'alias': 'southern', 'title': 'Southern'}, {...     4.0
# 4  [{'alias': 'bbq', 'title': 'Barbeque'}, {'alia...     4.5
#
#                                          coordinates        transactions  \
# 0     {'latitude': 29.94902, 'longitude': -90.13224}          [delivery]
# 1  {'latitude': 29.9942752940439, 'longitude': -9...            [pickup]
# 2     {'latitude': 29.95668, 'longitude': -90.06772}  [pickup, delivery]
# 3  {'latitude': 29.935093648757825, 'longitude': ...          [delivery]
# 4  {'latitude': 29.949828919319, 'longitude': -90...  [pickup, delivery]
#
#   price                                           location         phone  \
# 0   $$$  {'address1': '8324 Oak St', 'address2': '', 'a...  +15048610886
# 1    $$  {'address1': '2309 N Causeway Blvd', 'address2...  +15048352022
# 2    $$  {'address1': '411 Bourbon St', 'address2': '',...  +15044073717
# 3    $$  {'address1': '4500 Freret St', 'address2': '',...  +15047541336
# 4    $$  {'address1': '8115 Jeannette St', 'address2': ...  +15048625514
#
#     display_phone     distance
# 0  (504) 861-0886   807.133049
# 1  (504) 835-2022  5947.073272
# 2  (504) 407-3717  5506.406814
# 3  (504) 754-1336  2377.358283
# 4  (504) 862-5514   419.599667

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/New Orleans-Gumbo.csv.gz'

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression='gzip', index=False)
